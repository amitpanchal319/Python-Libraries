# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\SqyUser\Desktop\Python\8 New Project data cleaning n Analysis\Project 4.csv")

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
data.shape
# Out:
# (321, 6)

# %%
data.count()
# Out:
# Date         140
# State        140
# Region       140
# Confirmed    140
# Deaths       140
# Recovered    140
# dtype: int64

# %%
data.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
data.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
data.dropna(subset=['State'],inplace = True)

# %%
data.isnull().sum()
# Out:
# Date         0
# State        0
# Region       0
# Confirmed    0
# Deaths       0
# Recovered    0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd

# %% [markdown]
# # show the number is confirmed, death and recovered cases in each region.

# %%
data.head(2)
# Out:
#           Date    State Region  Confirmed  Deaths  Recovered
# 181  4/29/2020  Alabama     US       6912     256          0
# 182  4/29/2020   Alaska     US        355       9          0

# %%
data.groupby('Region').sum().head(20)
# Out:
#                                                              Date  \
# Region
# Australia       4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Canada          4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Denmark                                        4/29/20204/29/2020
# France          4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Hong Kong                                               4/29/2020
# Macau                                                   4/29/2020
# Mainland China  4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Netherlands                  4/29/20204/29/20204/29/20204/29/2020
# UK              4/29/20204/29/20204/29/20204/29/20204/29/20204...
# US              4/29/20204/29/20204/29/20204/29/20204/29/20204...
#
#                                                             State  Confirmed  \
# Region
# Australia       Australian Capital TerritoryNew South WalesNor...       6752
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending =False)
# Out:
# Region
# US                1039909
# Mainland China      82862
# Canada              52865
# Australia            6752
# France               1450
# UK                   1220
# Hong Kong            1037
# Denmark               198
# Netherlands           196
# Macau                  45
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Deaths'].sum().sort_values(ascending =False).head(10)
# Out:
# Region
# US                60967
# Mainland China     4633
# Canada             3155
# Australia            91
# UK                   69
# France               34
# Netherlands          16
# Hong Kong             4
# Denmark               0
# Macau                 0
# Name: Deaths, dtype: int64

# %%
data.groupby('Region')[['Confirmed', 'Recovered']].sum()
# Out:
#                 Confirmed  Recovered
# Region
# Australia            6752       5715
# Canada              52865      20327
# Denmark               198        192
# France               1450        890
# Hong Kong            1037        830
# Macau                  45         34
# Mainland China      82862      77610
# Netherlands           196        119
# UK                   1220        857
# US                1039909     120720

# %% [markdown]
# Q2) remove all the records where Confirmed cases is less than 10.

# %%
data.head(2)
# Out:
#           Date    State Region  Confirmed  Deaths  Recovered
# 181  4/29/2020  Alabama     US       6912     256          0
# 182  4/29/2020   Alaska     US        355       9          0

# %%
data[data['Confirmed'] <10]
# Out:
#           Date                             State          Region  Confirmed  \
# 184  4/29/2020                          Anguilla              UK          3
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba     Netherlands          5
# 194  4/29/2020            British Virgin Islands              UK          6
# 203  4/29/2020      Diamond Princess cruise ship          Canada          0
# 272  4/29/2020             Northwest Territories          Canada          5
# 284  4/29/2020                         Recovered          Canada          0
# 285  4/29/2020                         Recovered              US          0
# 288  4/29/2020                  Saint Barthelemy          France          6
# 289  4/29/2020         Saint Pierre and Miquelon          France          1
# 305  4/29/2020                             Tibet  Mainland China          1
#
#      Deaths  Recovered
# 184       0          3
# 192       0          0
# 194       1          3
# 203       1          0
# ...

# %%
data[~(data.Confirmed<10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 181  4/29/2020   Alabama              US       6912     256          0
# 182  4/29/2020    Alaska              US        355       9          0
# 183  4/29/2020   Alberta          Canada       5165      87          0
# 185  4/29/2020     Anhui  Mainland China        991       6        985
# 186  4/29/2020   Arizona              US       7209     308          0
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [130 rows x 6 columns]

# %%
data = data[~(data.Confirmed<10)]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 181  4/29/2020   Alabama              US       6912     256          0
# 182  4/29/2020    Alaska              US        355       9          0
# 183  4/29/2020   Alberta          Canada       5165      87          0
# 185  4/29/2020     Anhui  Mainland China        991       6        985
# 186  4/29/2020   Arizona              US       7209     308          0
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [130 rows x 6 columns]

# %%
data.head(20)
# Out:
#           Date                         State          Region  Confirmed  \
# 181  4/29/2020                       Alabama              US       6912
# 182  4/29/2020                        Alaska              US        355
# 183  4/29/2020                       Alberta          Canada       5165
# 185  4/29/2020                         Anhui  Mainland China        991
# 186  4/29/2020                       Arizona              US       7209
# 187  4/29/2020                      Arkansas              US       3193
# 188  4/29/2020                         Aruba     Netherlands        100
# 189  4/29/2020  Australian Capital Territory       Australia        106
# 190  4/29/2020                       Beijing  Mainland China        593
# 191  4/29/2020                       Bermuda              UK        111
# 193  4/29/2020              British Columbia          Canada       2087
# 195  4/29/2020                    California              US      48747
# ...

# %% [markdown]
# Q3) In which Region, Maximum number of confirmed cases were recorded ?

# %%
data.head(2)
# Out:
#           Date    State Region  Confirmed  Deaths  Recovered
# 181  4/29/2020  Alabama     US       6912     256          0
# 182  4/29/2020   Alaska     US        355       9          0

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US                1039909
# Mainland China      82861
# Canada              52860
# Australia            6752
# France               1443
# UK                   1211
# Hong Kong            1037
# Denmark               198
# Netherlands           191
# Macau                  45
# Name: Confirmed, dtype: int64

# %% [markdown]
# Q4) In which region, Minimum number of Death cases were recorded ?

# %%
data.groupby('Region')['Deaths'].sum().sort_values(ascending = True)
# Out:
# Region
# Denmark               0
# Macau                 0
# Hong Kong             4
# Netherlands          16
# France               34
# UK                   68
# Australia            91
# Canada             3154
# Mainland China     4633
# US                60967
# Name: Deaths, dtype: int64

# %% [markdown]
# Q5) How many confirmed, Deaths & Recovered cases were reported from india till 29 April 20 ?

# %%
data[data['Region'] == 'US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# Q6) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
data.sort_values(by=['Confirmed'], ascending = True).head(50)
# Out:
#           Date                         State          Region  Confirmed  \
# 256  4/29/2020                    Montserrat              UK         11
# 217  4/29/2020                     Greenland         Denmark         11
# 318  4/29/2020                         Yukon          Canada         11
# 306  4/29/2020      Turks and Caicos Islands              UK         12
# 215  4/29/2020                Grand Princess          Canada         13
# 206  4/29/2020   Falkland Islands (Malvinas)              UK         13
# 270  4/29/2020      Northern Mariana Islands              US         14
# 201  4/29/2020                       Curacao     Netherlands         16
# 260  4/29/2020                 New Caledonia          France         18
# 281  4/29/2020                       Qinghai  Mainland China         18
# 279  4/29/2020          Prince Edward Island          Canada         27
# 271  4/29/2020            Northern Territory       Australia         28
# ...

# %% [markdown]
# Q6-B) Sore the entire data wrt number of Recovered cases in descending order.

# %%
data.sort_values(by= ['Recovered'], ascending = False)
# Out:
#           Date            State          Region  Confirmed  Deaths  Recovered
# 229  4/29/2020            Hubei  Mainland China      68128    4512      63616
# 264  4/29/2020  New South Wales       Australia       3016      40       2284
# 220  4/29/2020        Guangdong  Mainland China       1588       8       1557
# 309  4/29/2020         Victoria       Australia       1361      18       1291
# 320  4/29/2020         Zhejiang  Mainland China       1268       1       1263
# ..         ...              ...             ...        ...     ...        ...
# 254  4/29/2020         Missouri              US       7660     338          0
# 253  4/29/2020      Mississippi              US       6569     250          0
# 252  4/29/2020        Minnesota              US       4644     319          0
# 251  4/29/2020         Michigan              US      40399    3670          0
# 181  4/29/2020          Alabama              US       6912     256          0
#
# [130 rows x 6 columns]
