# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\SqyUser\Desktop\learning Classes\Python\vaibhav.csv")

# %%
df.head()
# Out:
#    SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0     1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1     2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2     3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3     4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4     5.0   M1  HW4S  Left Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Markup  \
# 0  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 1  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 2  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 3  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 4  Frosty White 22291(SF)_8MR_Frosty White 22291(SF)  ...            1.95
#
#    Bot Lam Wastage  Bot Lam \nPrice  Edge Band \nBase Price  \
# 0             1.25           607.18                   63.45
# 1             1.25           607.18                   63.45
# 2             1.25           452.20                   63.45
# 3             1.25           452.20                   63.45
# 4             1.25           775.42                    0.00
#
#    Edge Band\nLength  Edge Band\nPrice  Total Customer Price  \
# 0               5.44            345.17              4,710.62
# 1               5.44            345.17              4,710.62
# 2               4.37            277.15              3,528.37
# 3               4.37            277.15              3,528.37
# 4               0.00              0.00              4,525.27
#
#    Total Vendor Price  Percentage Vendor vs Customer  Unnamed: 42
# 0             1948.78                         41.37%          NaN
# 1             1948.78                         41.37%          NaN
# 2             1456.19                         41.27%          NaN
# 3             1456.19                         41.27%          NaN
# 4             1883.61                         41.62%          NaN
#
# [5 rows x 43 columns]

# %%
df = pd.read_csv(r"C:\Users\SqyUser\Desktop\learning Classes\Python\vaibhav.csv")

# %%
df.head()
# Out:
#    SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0     1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1     2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2     3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3     4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4     5.0   M1  HW4S  Left Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Markup  \
# 0  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 1  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 2  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 3  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 4  Frosty White 22291(SF)_8MR_Frosty White 22291(SF)  ...            1.95
#
#    Bot Lam Wastage  Bot Lam \nPrice  Edge Band \nBase Price  \
# 0             1.25           607.18                   63.45
# 1             1.25           607.18                   63.45
# 2             1.25           452.20                   63.45
# 3             1.25           452.20                   63.45
# 4             1.25           775.42                    0.00
#
#    Edge Band\nLength  Edge Band\nPrice  Total Customer Price  \
# 0               5.44            345.17              4,710.62
# 1               5.44            345.17              4,710.62
# 2               4.37            277.15              3,528.37
# 3               4.37            277.15              3,528.37
# 4               0.00              0.00              4,525.27
#
#    Total Vendor Price  Percentage Vendor vs Customer  Unnamed: 42
# 0             1948.78                         41.37%          NaN
# 1             1948.78                         41.37%          NaN
# 2             1456.19                         41.27%          NaN
# 3             1456.19                         41.27%          NaN
# 4             1883.61                         41.62%          NaN
#
# [5 rows x 43 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'HEIGHT', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer', 'Unnamed: 42'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['SL\nNO',
#  'POSN',
#  'CODE',
#  'DESCRIPTION',
#  'TYPE',
#  'GROOVE',
#  'EXTERNAL SHADE',
#  'PANEL CORE',
#  'INTERNAL SHADE',
#  'BOARD NAME',
#  'GRAIN',
#  'WIDTH',
#  'HEIGHT',
#  'THK',
#  'Sq Feet',
#  'Edge Bending Rate',
#  'Plywood',
#  'Internal laminate',
#  'External laminate',
#  'Processing Cost',
#  'Core Price',
#  'Plywood + Processing',
#  'Edge Banding Length & Price',
#  'Panel Price',
#  'Core \nBase Price',
#  'Core \nMarkup',
#  'Core \nWastage',
#  'Core Total Price',
#  'Top Lam Base Price',
#  'Top Lam Markup',
#  'Top Lam Wastge',
#  'Top Lam \nPrice',
#  'Bot Lam Base Price',
#  'Bot Lam Markup',
#  'Bot Lam Wastage',
#  'Bot Lam \nPrice',
#  'Edge Band \nBase Price',
#  'Edge Band\nLength',
#  'Edge Band\nPrice',
#  'Total Customer Price',
#  'Total Vendor Price',
#  'Percentage Vendor vs Customer',
#  'Unnamed: 42']

# %%
df.head()
# Out:
#    SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0     1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1     2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2     3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3     4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4     5.0   M1  HW4S  Left Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Markup  \
# 0  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 1  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 2  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 3  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...            1.95
# 4  Frosty White 22291(SF)_8MR_Frosty White 22291(SF)  ...            1.95
#
#    Bot Lam Wastage  Bot Lam \nPrice  Edge Band \nBase Price  \
# 0             1.25           607.18                   63.45
# 1             1.25           607.18                   63.45
# 2             1.25           452.20                   63.45
# 3             1.25           452.20                   63.45
# 4             1.25           775.42                    0.00
#
#    Edge Band\nLength  Edge Band\nPrice  Total Customer Price  \
# 0               5.44            345.17              4,710.62
# 1               5.44            345.17              4,710.62
# 2               4.37            277.15              3,528.37
# 3               4.37            277.15              3,528.37
# 4               0.00              0.00              4,525.27
#
#    Total Vendor Price  Percentage Vendor vs Customer  Unnamed: 42
# 0             1948.78                         41.37%          NaN
# 1             1948.78                         41.37%          NaN
# 2             1456.19                         41.27%          NaN
# 3             1456.19                         41.27%          NaN
# 4             1883.61                         41.62%          NaN
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 500  Shutter    NaN  Toned Blue 22212 MR PLUS
# 501    Panel    NaN             White 1103 SD
# 502    Panel    NaN             White 1103 SD
# 503    Panel    NaN             White 1103 SD
# 504      NaN    NaN                       NaN
#
#                                             PANEL CORE  \
# 500    HDHMR or Equivalent - Action Tesa or Equivalent
# 501  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 502  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 503  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 504                                                NaN
#
#                    INTERNAL SHADE  \
# 500  Frosty White 22191-22291(SF)
# 501                 White 1103 SD
# 502                 White 1103 SD
# 503                 White 1103 SD
# 504                           NaN
#
#                                             BOARD NAME  ...  Bot Lam Markup  \
# 500  Toned Blue 22212 MR PLUS_18HDHMR or Equivalent...  ...             1.8
# 501  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...             0.0
# 502  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...             0.0
# 503  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...             0.0
# 504                                                NaN  ...             NaN
#
#      Bot Lam Wastage  Bot Lam \nPrice  Edge Band \nBase Price  \
# 500             1.25            70.55                  110.00
# 501             0.00             0.00                   63.45
# 502             0.00             0.00                   63.45
# 503             0.00             0.00                   63.45
# 504              NaN              NaN                     NaN
#
#      Edge Band\nLength  Edge Band\nPrice  Total Customer Price  \
# 500               1.91            209.88              1,141.80
# 501               1.35             85.53                371.43
# 502               1.91            121.06                808.40
# 503               1.81            114.72                672.02
# 504                NaN               NaN            512,895.59
#
#      Total Vendor Price  Percentage Vendor vs Customer  Unnamed: 42
# 500              473.18                         41.44%          NaN
# 501              139.26                         37.49%          NaN
# 502              314.97                         38.96%          NaN
# 503              259.38                         38.60%          NaN
# 504          224,215.97                         43.72%          NaN
#
# [5 rows x 43 columns]

# %%
df.tail(3)
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION   TYPE  \
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)  Panel
# 503   107.0  M25                 VGP-CF                Vertical Panel  Panel
# 504     NaN  NaN                    NaN                           NaN    NaN
#
#     GROOVE EXTERNAL SHADE                                         PANEL CORE  \
# 502    NaN  White 1103 SD  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 503    NaN  White 1103 SD  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 504    NaN            NaN                                                NaN
#
#     INTERNAL SHADE                                         BOARD NAME  ...  \
# 502  White 1103 SD  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 503  White 1103 SD  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 504            NaN                                                NaN  ...
#
#      Bot Lam Markup  Bot Lam Wastage  Bot Lam \nPrice  Edge Band \nBase Price  \
# 502             0.0              0.0              0.0                   63.45
# 503             0.0              0.0              0.0                   63.45
# 504             NaN              NaN              NaN                     NaN
#
#      Edge Band\nLength  Edge Band\nPrice  Total Customer Price  \
# 502               1.91            121.06                808.40
# 503               1.81            114.72                672.02
# 504                NaN               NaN            512,895.59
#
#      Total Vendor Price  Percentage Vendor vs Customer  Unnamed: 42
# 502              314.97                         38.96%          NaN
# 503              259.38                         38.60%          NaN
# 504          224,215.97                         43.72%          NaN
#
# [3 rows x 43 columns]

# %%
df.dtypes
# Out:
# SL\nNO                           float64
# POSN                              object
# CODE                              object
# DESCRIPTION                       object
# TYPE                              object
# GROOVE                            object
# EXTERNAL SHADE                    object
# PANEL CORE                        object
# INTERNAL SHADE                    object
# BOARD NAME                        object
# GRAIN                            float64
# WIDTH                            float64
# HEIGHT                           float64
# THK                              float64
# Sq Feet                          float64
# Edge Bending Rate                float64
# Plywood                          float64
# Internal laminate                float64
# External laminate                float64
# Processing Cost                  float64
# Core Price                       float64
# Plywood + Processing             float64
# Edge Banding Length & Price      float64
# Panel Price                      float64
# Core \nBase Price                float64
# Core \nMarkup                    float64
# Core \nWastage                   float64
# Core Total Price                  object
# Top Lam Base Price               float64
# Top Lam Markup                   float64
# Top Lam Wastge                   float64
# Top Lam \nPrice                   object
# Bot Lam Base Price               float64
# Bot Lam Markup                   float64
# Bot Lam Wastage                  float64
# Bot Lam \nPrice                  float64
# Edge Band \nBase Price           float64
# Edge Band\nLength                float64
# Edge Band\nPrice                 float64
# Total Customer Price              object
# Total Vendor Price                object
# Percentage Vendor vs Customer     object
# Unnamed: 42                      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'HEIGHT', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer', 'Unnamed: 42'],
#       dtype='object')

# %%
df['Sq Feet']
# Out:
# 0      13.11
# 1      13.11
# 2       9.76
# 3       9.76
# 4      16.74
#        ...
# 500     2.09
# 501     0.93
# 502     2.25
# 503     1.82
# 504      NaN
# Name: Sq Feet, Length: 505, dtype: float64

# %%
type(df['Sq Feet'])
# Out:
# pandas.core.series.Series

# %%
list(df['Sq Feet'])
# Out:
# [13.11,
#  13.11,
#  9.76,
#  9.76,
#  16.74,
#  16.74,
#  12.26,
#  1.68,
#  1.68,
#  1.72,
#  8.56,
#  8.56,
#  8.56,
#  8.56,
#  0.24,
#  0.48,
#  0.48,
#  0.32,
#  1.45,
#  0.58,
#  0.81,
#  0.81,
#  0.78,
#  0.32,
#  1.45,
#  0.48,
#  0.48,
#  0.24,
#  0.58,
#  4.18,
#  0.55,
#  0.48,
#  0.48,
#  0.73,
#  3.2,
#  1.17,
#  0.81,
#  0.81,
#  4.18,
#  4.17,
#  4.17,
#  5.76,
#  2.04,
#  2.04,
#  1.58,
#  1.58,
#  4.52,
#  4.52,
#  1.11,
#  1.11,
#  11.27,
#  0.55,
#  0.55,
#  0.59,
#  11.79,
#  3.88,
#  2.71,
#  0.28,
#  1.55,
#  2.58,
#  2.58,
#  2.58,
#  2.58,
#  1.17,
#  2.36,
#  2.36,
#  2.36,
#  2.36,
#  0.9,
#  0.9,
#  0.59,
#  0.59,
#  0.9,
#  0.57,
#  0.57,
#  0.57,
#  7.17,
#  5.81,
#  11.63,
#  5.81,
#  0.75,
#  0.75,
#  6.65,
#  6.65,
#  3.43,
#  0.57,
#  0.57,
#  1.27,
#  1.27,
#  1.27,
#  4.55,
#  4.55,
#  3.87,
#  3.87,
#  7.11,
#  0.62,
#  0.62,
#  1.23,
#  0.09,
#  0.09,
#  0.09,
#  0.62,
#  0.62,
#  2.06,
#  0.17,
#  0.17,
#  0.17,
#  0.43,
#  0.43,
#  4.05,
#  0.23,
#  0.23,
#  0.23,
#  1.26,
#  1.26,
#  3.7,
#  3.7,
#  1.08,
#  3.47,
#  0.82,
#  0.86,
#  1.19,
#  1.14,
#  0.55,
#  4.52,
#  4.52,
#  1.11,
#  1.11,
#  11.27,
#  0.95,
#  0.59,
#  11.79,
#  0.84,
#  0.57,
#  0.57,
#  2.26,
#  2.0,
#  0.67,
#  0.75,
#  0.25,
#  1.48,
#  0.26,
#  0.26,
#  0.14,
#  1.14,
#  13.11,
#  13.11,
#  9.76,
#  9.76,
#  16.74,
#  16.74,
#  12.26,
#  1.68,
#  1.68,
#  1.72,
#  8.56,
#  8.56,
#  8.56,
#  8.56,
#  0.24,
#  0.48,
#  0.48,
#  0.32,
#  1.45,
#  0.58,
#  0.81,
#  0.81,
#  0.78,
#  0.32,
#  1.45,
#  0.48,
#  0.48,
#  0.24,
#  0.58,
#  4.18,
#  0.56,
#  0.48,
#  0.48,
#  0.75,
#  3.28,
#  1.2,
#  0.81,
#  4.18,
#  5.75,
#  1.99,
#  4.17,
#  4.17,
#  1.99,
#  3.88,
#  2.58,
#  2.58,
#  1.0,
#  1.0,
#  6.08,
#  6.49,
#  0.76,
#  0.76,
#  0.76,
#  0.76,
#  0.28,
#  1.35,
#  2.58,
#  2.58,
#  2.58,
#  2.58,
#  2.36,
#  2.36,
#  2.36,
#  2.36,
#  1.17,
#  5.5,
#  1.94,
#  1.94,
#  2.63,
#  2.63,
#  5.17,
#  2.79,
#  2.79,
#  2.21,
#  0.19,
#  0.19,
#  0.64,
#  0.19,
#  0.19,
#  0.64,
#  3.2,
#  3.2,
#  3.07,
#  3.07,
#  6.95,
#  0.44,
#  0.46,
#  3.63,
#  3.63,
#  2.64,
#  3.2,
#  3.2,
#  1.37,
#  1.37,
#  3.18,
#  1.26,
#  0.2,
#  0.22,
#  0.85,
#  0.41,
#  0.95,
#  0.41,
#  0.41,
#  0.33,
#  2.56,
#  1.18,
#  2.11,
#  2.11,
#  1.25,
#  1.25,
#  2.27,
#  0.39,
#  0.39,
#  1.02,
#  0.16,
#  0.16,
#  0.46,
#  0.16,
#  0.16,
#  0.46,
#  6.61,
#  0.27,
#  0.27,
#  0.57,
#  0.27,
#  0.27,
#  0.57,
#  6.38,
#  6.38,
#  0.65,
#  0.27,
#  0.27,
#  0.6,
#  0.27,
#  0.27,
#  0.6,
#  4.31,
#  4.31,
#  4.15,
#  3.23,
#  3.23,
#  2.43,
#  2.43,
#  4.54,
#  2.4,
#  2.4,
#  3.23,
#  3.23,
#  1.95,
#  1.95,
#  3.68,
#  3.93,
#  4.31,
#  4.31,
#  3.04,
#  3.04,
#  4.23,
#  0.61,
#  0.65,
#  2.24,
#  2.24,
#  2.74,
#  13.11,
#  13.11,
#  9.14,
#  9.14,
#  21.0,
#  10.35,
#  12.26,
#  1.58,
#  1.58,
#  1.61,
#  10.71,
#  10.71,
#  10.71,
#  5.35,
#  2.55,
#  0.72,
#  0.48,
#  0.48,
#  0.96,
#  4.21,
#  1.52,
#  0.81,
#  0.81,
#  5.36,
#  0.3,
#  0.48,
#  0.48,
#  0.41,
#  1.81,
#  0.69,
#  0.81,
#  0.81,
#  2.56,
#  2.55,
#  2.55,
#  4.52,
#  4.52,
#  1.11,
#  1.11,
#  11.27,
#  0.95,
#  0.59,
#  11.79,
#  0.84,
#  1.14,
#  4.46,
#  3.42,
#  1.71,
#  1.71,
#  0.91,
#  0.91,
#  1.32,
#  0.28,
#  0.28,
#  0.74,
#  3.79,
#  3.79,
#  6.07,
#  0.41,
#  2.51,
#  0.61,
#  0.34,
#  2.15,
#  0.27,
#  0.27,
#  0.2,
#  0.61,
#  0.34,
#  2.15,
#  0.27,
#  0.27,
#  0.2,
#  1.61,
#  1.61,
#  2.79,
#  2.79,
#  4.53,
#  2.4,
#  2.4,
#  2.34,
#  0.81,
#  1.28,
#  2.58,
#  2.58,
#  2.58,
#  2.58,
#  2.42,
#  2.95,
#  2.95,
#  1.17,
#  0.54,
#  0.54,
#  1.43,
#  1.43,
#  1.53,
#  0.71,
#  0.71,
#  0.11,
#  0.11,
#  0.19,
#  0.81,
#  0.81,
#  0.61,
#  4.58,
#  0.09,
#  0.09,
#  0.81,
#  0.39,
#  0.39,
#  0.81,
#  0.51,
#  0.51,
#  0.81,
#  0.39,
#  0.39,
#  0.81,
#  0.81,
#  0.81,
#  0.45,
#  3.66,
#  0.53,
#  0.53,
#  0.81,
#  2.13,
#  2.13,
#  1.12,
#  1.12,
#  2.05,
#  2.13,
#  2.13,
#  2.0,
#  0.61,
#  3.95,
#  2.13,
#  2.13,
#  1.12,
#  1.12,
#  2.05,
#  0.14,
#  0.14,
#  0.18,
#  0.18,
#  0.46,
#  3.63,
#  3.63,
#  3.28,
#  3.28,
#  3.89,
#  2.13,
#  2.13,
#  1.65,
#  1.65,
#  2.99,
#  3.29,
#  1.41,
#  2.13,
#  2.13,
#  2.78,
#  2.78,
#  4.98,
#  2.13,
#  2.76,
#  0.79,
#  0.26,
#  2.38,
#  2.13,
#  2.13,
#  3.42,
#  3.42,
#  6.1,
#  3.29,
#  3.29,
#  2.92,
#  2.07,
#  4.92,
#  4.92,
#  1.52,
#  0.51,
#  0.51,
#  0.81,
#  4.92,
#  4.92,
#  3.31,
#  3.31,
#  5.4,
#  4.52,
#  4.52,
#  0.92,
#  0.33,
#  2.25,
#  0.92,
#  0.33,
#  2.25,
#  2.09,
#  0.93,
#  2.25,
#  1.82,
#  nan]

# %%
df.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'HEIGHT', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer', 'Unnamed: 42'],
#       dtype='object')

# %%
df[['Sq Feet']]
# Out:
#      Sq Feet
# 0      13.11
# 1      13.11
# 2       9.76
# 3       9.76
# 4      16.74
# ..       ...
# 500     2.09
# 501     0.93
# 502     2.25
# 503     1.82
# 504      NaN
#
# [505 rows x 1 columns]

# %%
 type(df[['Sq Feet']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'HEIGHT', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer', 'Unnamed: 42'],
#       dtype='object')

# %%
df[['Sq Feet', 'Edge Bending Rate']]
# Out:
#      Sq Feet  Edge Bending Rate
# 0      13.11              16.25
# 1      13.11              16.25
# 2       9.76              16.25
# 3       9.76              16.25
# 4      16.74               0.00
# ..       ...                ...
# 500     2.09              37.00
# 501     0.93              16.25
# 502     2.25              16.25
# 503     1.82              16.25
# 504      NaN                NaN
#
# [505 rows x 2 columns]

# %%
df [['Sq Feet', 'Edge Bending Rate', 'Plywood',
       'Internal laminate', 'External laminate', 'Processing Cost',]]
# Out:
#      Sq Feet  Edge Bending Rate  Plywood  Internal laminate  \
# 0      13.11              16.25     60.0               16.0
# 1      13.11              16.25     60.0               16.0
# 2       9.76              16.25     60.0               16.0
# 3       9.76              16.25     60.0               16.0
# 4      16.74               0.00     30.5               16.0
# ..       ...                ...      ...                ...
# 500     2.09              37.00     64.0               16.0
# 501     0.93              16.25     86.0                0.0
# 502     2.25              16.25     86.0                0.0
# 503     1.82              16.25     86.0                0.0
# 504      NaN                NaN      NaN                NaN
#
#      External laminate  Processing Cost
# 0                 16.0             50.0
# 1                 16.0             50.0
# 2                 16.0             50.0
# 3                 16.0             50.0
# 4                 16.0             50.0
# ..                 ...              ...
# 500               64.0             50.0
# 501                0.0             41.0
# 502                0.0             41.0
# 503                0.0             41.0
# 504                NaN              NaN
#
# [505 rows x 6 columns]

# %%
df1 = pd.read_excel(r"C:\Users\SqyUser\Desktop\Modular Margin Analysis\Vaibhav Pagare 199981\vaibhav.xlsx")

# %%
df1
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 3       4.0   M1                   HW4S                  Bottom Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# 1      Panel      G    Frosty White 22291(SF)
# 2      Panel      G    Frosty White 22291(SF)
# 3      Panel      G    Frosty White 22291(SF)
# 4      Panel    NaN    Frosty White 22291(SF)
# ..       ...    ...                       ...
# 500  Shutter    NaN  Toned Blue 22212 MR PLUS
# 501    Panel    NaN             White 1103 SD
# 502    Panel    NaN             White 1103 SD
# 503    Panel    NaN             White 1103 SD
# 504      NaN    NaN                       NaN
#
#                                             PANEL CORE  \
# 0                     MR - Green/Century or Equivalent
# 1                     MR - Green/Century or Equivalent
# 2                     MR - Green/Century or Equivalent
# 3                     MR - Green/Century or Equivalent
# 4                     MR - Green/Century or Equivalent
# ..                                                 ...
# 500    HDHMR or Equivalent - Action Tesa or Equivalent
# 501  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 502  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 503  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 504                                                NaN
#
#                    INTERNAL SHADE  \
# 0          Frosty White 22291(SF)
# 1          Frosty White 22291(SF)
# 2          Frosty White 22291(SF)
# 3          Frosty White 22291(SF)
# 4          Frosty White 22291(SF)
# ..                            ...
# 500  Frosty White 22191-22291(SF)
# 501                 White 1103 SD
# 502                 White 1103 SD
# 503                 White 1103 SD
# 504                           NaN
#
#                                             BOARD NAME  ...  \
# 0    Frosty White 22291(SF)_18MR_Frosty White 22291...  ...
# 1    Frosty White 22291(SF)_18MR_Frosty White 22291...  ...
# 2    Frosty White 22291(SF)_18MR_Frosty White 22291...  ...
# 3    Frosty White 22291(SF)_18MR_Frosty White 22291...  ...
# 4    Frosty White 22291(SF)_8MR_Frosty White 22291(SF)  ...
# ..                                                 ...  ...
# 500  Toned Blue 22212 MR PLUS_18HDHMR or Equivalent...  ...
# 501  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 502  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 503  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 504                                                NaN  ...
#
#      Bot Lam Base Price  Bot Lam Markup  Bot Lam Wastage  Bot Lam \nPrice  \
# 0                  19.0            1.95             1.25       607.177648
# 1                  19.0            1.95             1.25       607.177648
# 2                  19.0            1.95             1.25       452.202781
# 3                  19.0            1.95             1.25       452.202781
# 4                  19.0            1.95             1.25       775.419694
# ..                  ...             ...              ...              ...
# 500                15.0            1.80             1.25        70.552296
# 501                 0.0            0.00             0.00         0.000000
# 502                 0.0            0.00             0.00         0.000000
# 503                 0.0            0.00             0.00         0.000000
# 504                 NaN             NaN              NaN              NaN
#
#      Edge Band \nBase Price  Edge Band\nLength  Edge Band\nPrice  \
# 0                     63.45              5.440          345.1680
# 1                     63.45              5.440          345.1680
# 2                     63.45              4.368          277.1496
# 3                     63.45              4.368          277.1496
# 4                      0.00              0.000            0.0000
# ..                      ...                ...               ...
# 500                  110.00              1.908          209.8800
# 501                   63.45              1.348           85.5306
# 502                   63.45              1.908          121.0626
# 503                   63.45              1.808          114.7176
# 504                     NaN                NaN               NaN
#
#      Total Customer Price  Total Vendor Price  Percentage Vendor vs Customer
# 0             4710.619600         1948.783692                       0.413700
# 1             4710.619600         1948.783692                       0.413700
# 2             3528.371649         1456.191092                       0.412709
# 3             3528.371649         1456.191092                       0.412709
# 4             4525.269807         1883.610594                       0.416243
# ..                    ...                 ...                            ...
# 500           1141.797445          473.181052                       0.414418
# 501            371.428795          139.262094                       0.374936
# 502            808.404021          314.974152                       0.389625
# 503            672.021455          259.379312                       0.385969
# 504         512895.585353       224215.967890                       0.437157
#
# [505 rows x 42 columns]

# %%
df1.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'HEIGHT', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer'],
#       dtype='object')

# %%
df1.head()
# Out:
#    SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0     1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1     2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2     3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3     4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4     5.0   M1  HW4S  Left Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Base Price  \
# 0  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...                19.0
# 1  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...                19.0
# 2  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...                19.0
# 3  Frosty White 22291(SF)_18MR_Frosty White 22291...  ...                19.0
# 4  Frosty White 22291(SF)_8MR_Frosty White 22291(SF)  ...                19.0
#
#    Bot Lam Markup  Bot Lam Wastage  Bot Lam \nPrice  Edge Band \nBase Price  \
# 0            1.95             1.25       607.177648                   63.45
# 1            1.95             1.25       607.177648                   63.45
# 2            1.95             1.25       452.202781                   63.45
# 3            1.95             1.25       452.202781                   63.45
# 4            1.95             1.25       775.419694                    0.00
#
#    Edge Band\nLength  Edge Band\nPrice  Total Customer Price  \
# 0              5.440          345.1680           4710.619600
# 1              5.440          345.1680           4710.619600
# 2              4.368          277.1496           3528.371649
# 3              4.368          277.1496           3528.371649
# 4              0.000            0.0000           4525.269807
#
#    Total Vendor Price  Percentage Vendor vs Customer
# 0         1948.783692                       0.413700
# 1         1948.783692                       0.413700
# 2         1456.191092                       0.412709
# 3         1456.191092                       0.412709
# 4         1883.610594                       0.416243
#
# [5 rows x 42 columns]

# %%
df1[['Total Customer Price', 'Total Vendor Price',
       'Percentage Vendor vs Customer']]
# Out:
#      Total Customer Price  Total Vendor Price  Percentage Vendor vs Customer
# 0             4710.619600         1948.783692                       0.413700
# 1             4710.619600         1948.783692                       0.413700
# 2             3528.371649         1456.191092                       0.412709
# 3             3528.371649         1456.191092                       0.412709
# 4             4525.269807         1883.610594                       0.416243
# ..                    ...                 ...                            ...
# 500           1141.797445          473.181052                       0.414418
# 501            371.428795          139.262094                       0.374936
# 502            808.404021          314.974152                       0.389625
# 503            672.021455          259.379312                       0.385969
# 504         512895.585353       224215.967890                       0.437157
#
# [505 rows x 3 columns]

# %%
df1.tail()
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 500  Shutter    NaN  Toned Blue 22212 MR PLUS
# 501    Panel    NaN             White 1103 SD
# 502    Panel    NaN             White 1103 SD
# 503    Panel    NaN             White 1103 SD
# 504      NaN    NaN                       NaN
#
#                                             PANEL CORE  \
# 500    HDHMR or Equivalent - Action Tesa or Equivalent
# 501  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 502  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 503  Lam HDHMR or Equivalent - White 1103 SD - Acti...
# 504                                                NaN
#
#                    INTERNAL SHADE  \
# 500  Frosty White 22191-22291(SF)
# 501                 White 1103 SD
# 502                 White 1103 SD
# 503                 White 1103 SD
# 504                           NaN
#
#                                             BOARD NAME  ...  \
# 500  Toned Blue 22212 MR PLUS_18HDHMR or Equivalent...  ...
# 501  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 502  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 503  PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...  ...
# 504                                                NaN  ...
#
#      Bot Lam Base Price  Bot Lam Markup  Bot Lam Wastage  Bot Lam \nPrice  \
# 500                15.0             1.8             1.25        70.552296
# 501                 0.0             0.0             0.00         0.000000
# 502                 0.0             0.0             0.00         0.000000
# 503                 0.0             0.0             0.00         0.000000
# 504                 NaN             NaN              NaN              NaN
#
#      Edge Band \nBase Price  Edge Band\nLength  Edge Band\nPrice  \
# 500                  110.00              1.908          209.8800
# 501                   63.45              1.348           85.5306
# 502                   63.45              1.908          121.0626
# 503                   63.45              1.808          114.7176
# 504                     NaN                NaN               NaN
#
#      Total Customer Price  Total Vendor Price  Percentage Vendor vs Customer
# 500           1141.797445          473.181052                       0.414418
# 501            371.428795          139.262094                       0.374936
# 502            808.404021          314.974152                       0.389625
# 503            672.021455          259.379312                       0.385969
# 504         512895.585353       224215.967890                       0.437157
#
# [5 rows x 42 columns]

# %%
df1.dtypes
# Out:
# SL\nNO                           float64
# POSN                              object
# CODE                              object
# DESCRIPTION                       object
# TYPE                              object
# GROOVE                            object
# EXTERNAL SHADE                    object
# PANEL CORE                        object
# INTERNAL SHADE                    object
# BOARD NAME                        object
# GRAIN                            float64
# WIDTH                            float64
# HEIGHT                           float64
# THK                              float64
# Sq Feet                          float64
# Edge Bending Rate                float64
# Plywood                          float64
# Internal laminate                float64
# External laminate                float64
# Processing Cost                  float64
# Core Price                       float64
# Plywood + Processing             float64
# Edge Banding Length & Price      float64
# Panel Price                      float64
# Core \nBase Price                float64
# Core \nMarkup                    float64
# Core \nWastage                   float64
# Core Total Price                 float64
# Top Lam Base Price               float64
# Top Lam Markup                   float64
# Top Lam Wastge                   float64
# Top Lam \nPrice                  float64
# Bot Lam Base Price               float64
# Bot Lam Markup                   float64
# Bot Lam Wastage                  float64
# Bot Lam \nPrice                  float64
# Edge Band \nBase Price           float64
# Edge Band\nLength                float64
# Edge Band\nPrice                 float64
# Total Customer Price             float64
# Total Vendor Price               float64
# Percentage Vendor vs Customer    float64
# dtype: object
