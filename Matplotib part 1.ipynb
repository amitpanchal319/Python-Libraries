# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x= np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.35116018, 0.6535128 , 0.53965368, 0.83179865, 0.47198489,
#        0.07539974, 0.73562903, 0.67695015, 0.47347403, 0.61973316,
#        0.88999663, 0.23011913, 0.26094169, 0.43738168, 0.5280488 ,
#        0.7668705 , 0.30085246, 0.21642599, 0.50636148, 0.04902338,
#        0.19647345, 0.50178691, 0.86336987, 0.61752655, 0.47184126,
#        0.53470481, 0.0048602 , 0.95049168, 0.48795851, 0.85116801,
#        0.04224272, 0.16940842, 0.93306278, 0.1704884 , 0.41492062,
#        0.2801537 , 0.03268514, 0.08016257, 0.2494931 , 0.22772874,
#        0.67361792, 0.53549145, 0.9798027 , 0.67705651, 0.87837221,
#        0.94725654, 0.53510396, 0.86575042, 0.87321911, 0.97616945])

# %%
y
# Out:
# array([0.56002758, 0.36027781, 0.56548406, 0.69691218, 0.61053712,
#        0.92492887, 0.65532289, 0.72876976, 0.55745827, 0.6196473 ,
#        0.78968509, 0.01298111, 0.77031532, 0.38526648, 0.29793276,
#        0.32219316, 0.6137784 , 0.16665604, 0.21925605, 0.41911656,
#        0.25698402, 0.09896123, 0.69345954, 0.86157464, 0.03556071,
#        0.78871822, 0.36117679, 0.77831415, 0.8552227 , 0.29003598,
#        0.93229539, 0.22083973, 0.63892166, 0.93406461, 0.91554895,
#        0.70246396, 0.93455379, 0.50776139, 0.33812221, 0.47373746,
#        0.0526653 , 0.73606677, 0.68979265, 0.52934611, 0.51530727,
#        0.67876301, 0.02499494, 0.73171135, 0.23357212, 0.19345152])

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
# Out:
# Text(0, 0.5, 'this is my y axis')

# %%
plt.scatter(x,y)
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is x vs y")
# Out:
# Text(0.5, 1.0, 'this is x vs y')

# %%
plt.scatter(x,y, c = 'r' )
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is x vs y")
# Out:
# Text(0.5, 1.0, 'this is x vs y')

# %%
plt.scatter(x,y, c = 'r', alpha=.9, marker = 'X' )
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is x vs y")
# Out:
# Text(0.5, 1.0, 'this is x vs y')

# %%
plt.scatter(x,y, c = 'r', alpha=.9, marker = 'X' )
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is x vs y")
plt.grid()

# %%
plt.scatter(x,y, c = 'r', alpha=.9, marker = 'X' )
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is x vs y")
plt.grid()
plt.figure(figsize=(6,2))

# %%
x = np.linspace(1,10,100)
y = np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
# ...

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y,c = 'r')

# %%
plt.plot(x,y, '--r')

# %%
plt.plot(x,y, '--r')
plt.figure(figsize=(8,2))

# %%
plt.plot(x,y, '--r')
plt.figure(figsize=(8,2))
plt.xlabel("this is x data")
plt.ylabel("this is y data")
plt.title("this is my sin wave graph")
# Out:
# Text(0.5, 1.0, 'this is my sin wave graph')

# %%
plt.plot(x,y, '--r')
plt.figure(figsize=(8,2))
plt.xlabel("this is x data")
plt.ylabel("this is y data")
plt.title("this is my sin wave graph")
plt.grid()

# %%
x = ['a','b','c','d','e']
y = np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.16689683, 0.47414199, 0.6247214 , 0.5329701 , 0.64381848])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x,y, color='b')
plt.xlabel("this is x my axis")
plt.ylabel("this is y my axis")
plt.title("this is my bar plot")
plt.grid()

# %%
plt.bar(x,y, color='b')
plt.xlabel("this is x my axis")
plt.ylabel("this is y my axis")
plt.title("this is my bar plot")
plt.grid()
plt.figure(figsize=(5,7))

# %%
plt.barh(x,y, color='b')
plt.xlabel("this is x my axis")
plt.ylabel("this is y my axis")
plt.title("this is my bar plot")
plt.grid()
plt.figure(figsize=(5,7))

# %%
x = [3,4,5,6,7,8]
y = [4,5,6,7,8,9]

# %%
plt.plot(x,y)
plt.figure(figsize=(6,2))

# %%
plt.scatter(x,y)
plt.figure(figsize=(6,2))

# %%
### for x axis graph show me the data of repeatitive values, while y axis graph show me the graph of unique values.

# %%
data = [1,2,3,4,5,6,7,8,6,6,7,7,8,8,9,5,5,5]

# %%
plt.hist(data)
plt.figure(figsize=(6,5))
plt.xlabel("these are repeat values")
plt.ylabel("these are unique values")
# Out:
# Text(0, 0.5, 'these are unique values')

# %%
plt.hist(data)
plt.figure(figsize=(5,3))
plt.xlabel("these are repeat values")
plt.ylabel("these are unique values")
plt.grid()

# %%
plt.savefig("test.png")
plt.hist(data)
plt.figure(figsize=(5,3))
plt.xlabel("these are repeat values")
plt.ylabel("these are unique values")
plt.grid()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z, c = '#932768', alpha = .8)
plt.show()
plt.xlabel("my x axis")
plt.ylabel("my y axis")
# Out:
# Text(0, 0.5, 'my y axis')
