# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\SqyUser\Desktop\learning Classes\Python\vaibhav.csv")

# %%
df.head()
# Out:
#    SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0     1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1     2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2     3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3     4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4     5.0   M1  HW4S  Left Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Markup  \
# ...

# %%
df.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'HEIGHT', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer', 'Unnamed: 42'],
#       dtype='object')

# %%
df['BOARD NAME']
# Out:
# 0      Frosty White 22291(SF)_18MR_Frosty White 22291...
# 1      Frosty White 22291(SF)_18MR_Frosty White 22291...
# 2      Frosty White 22291(SF)_18MR_Frosty White 22291...
# 3      Frosty White 22291(SF)_18MR_Frosty White 22291...
# 4      Frosty White 22291(SF)_8MR_Frosty White 22291(SF)
#                              ...
# 500    Toned Blue 22212 MR PLUS_18HDHMR or Equivalent...
# 501    PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...
# 502    PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...
# 503    PL_18-Lam HDHMR or Equivalent-White 1103 SD PL...
# 504                                                  NaN
# Name: BOARD NAME, Length: 505, dtype: object

# %%
df['BOARD NAME'][2:11]
# Out:
# 2     Frosty White 22291(SF)_18MR_Frosty White 22291...
# 3     Frosty White 22291(SF)_18MR_Frosty White 22291...
# 4     Frosty White 22291(SF)_8MR_Frosty White 22291(SF)
# 5     Frosty White 22291(SF)_8MR_Frosty White 22291(SF)
# 6     Frosty White 22291(SF)_18MR_Frosty White 22291...
# 7     Frosty White 22291(SF)_18MR_Frosty White 22291...
# 8     Frosty White 22291(SF)_18MR_Frosty White 22291...
# 9     Frosty White 21091 HGL_18MR_Frosty White 22291...
# 10    Frosty White 21091 HGL_18MR_Frosty White 22291...
# Name: BOARD NAME, dtype: object

# %%
len(df)
# Out:
# 505

# %%
l = [ 'a', 'b', 'c', 'd', 'e']

# %%
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
list(df['BOARD NAME'])
# Out:
# ['Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_8MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_8MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 21091 HGL_18MR_Frosty White 22291(SF)',
#  'Frosty White 21091 HGL_18MR_Frosty White 22291(SF)',
#  'Frosty White 21091 HGL_18MR_Frosty White 22291(SF)',
#  'Frosty White 21091 HGL_18MR_Frosty White 22291(SF)',
#  'Frosty White 21091 HGL_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
#  'Frosty White 22291(SF)_18MR_Frosty White 22291(SF)',
# ...

# %%
df['BOARD NAME'][2:7]
# Out:
# 2    Frosty White 22291(SF)_18MR_Frosty White 22291...
# 3    Frosty White 22291(SF)_18MR_Frosty White 22291...
# 4    Frosty White 22291(SF)_8MR_Frosty White 22291(SF)
# 5    Frosty White 22291(SF)_8MR_Frosty White 22291(SF)
# 6    Frosty White 22291(SF)_18MR_Frosty White 22291...
# Name: BOARD NAME, dtype: object

# %%
pd.Series(list(df['BOARD NAME'][2:7]), index = ['a','b', 'sudh', 'd','e'])
# Out:
# a       Frosty White 22291(SF)_18MR_Frosty White 22291...
# b       Frosty White 22291(SF)_18MR_Frosty White 22291...
# sudh    Frosty White 22291(SF)_8MR_Frosty White 22291(SF)
# d       Frosty White 22291(SF)_8MR_Frosty White 22291(SF)
# e       Frosty White 22291(SF)_18MR_Frosty White 22291...
# dtype: object

# %%
s = pd.Series(df['BOARD NAME'][2:7], index = ['a','b', 'sudh', 'd','e'])

# %%
s
# Out:
# a       NaN
# b       NaN
# sudh    NaN
# d       NaN
# e       NaN
# Name: BOARD NAME, dtype: object

# %%
s1 = df['BOARD NAME'][5:10]

# %%
 s+s1
# Out:
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# a       NaN
# b       NaN
# d       NaN
# e       NaN
# sudh    NaN
# Name: BOARD NAME, dtype: object

# %%
df
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 3       4.0   M1                   HW4S                  Bottom Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer', 'Unnamed: 42'],
#       dtype='object')

# %%
df.drop('Unnamed: 42', axis = 1, inplace = True)

# %%
df
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 3       4.0   M1                   HW4S                  Bottom Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df.drop(3)
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# 5       6.0   M1                   HW4S              Right Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 3       4.0   M1                   HW4S                  Bottom Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df.drop(3, inplace = True)

# %%
df
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# 5       6.0   M1                   HW4S              Right Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# 5       6.0   M1                   HW4S              Right Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
# make  POSN as a Index or any other column

# %%
df.set_index('POSN', inplace = True)

# %%
df
# Out:
#       SL\nNO                   CODE                   DESCRIPTION     TYPE  \
# POSN
# M1       1.0                   HW4S                    Left Panel    Panel
# M1       2.0                   HW4S                   Right Panel    Panel
# M1       3.0                   HW4S                     Top Panel    Panel
# M1       5.0                   HW4S               Left Back Panel    Panel
# M1       6.0                   HW4S              Right Back Panel    Panel
# ...      ...                    ...                           ...      ...
# M24    104.0  3D Base BothPanels-CK                 Bottom Drawer  Shutter
# M24    105.0  3D Base BothPanels-CK     Innotech Back Panel (Big)    Panel
# M24    106.0  3D Base BothPanels-CK  Innotech Bottom Panel (470D)    Panel
# M25    107.0                 VGP-CF                Vertical Panel    Panel
# NaN      NaN                    NaN                           NaN      NaN
#
#      GROOVE            EXTERNAL SHADE  \
# POSN
# ...

# %%
df.loc['M1']
# Out:
#       SL\nNO  CODE           DESCRIPTION   TYPE GROOVE  \
# POSN
# M1       1.0  HW4S            Left Panel  Panel      G
# M1       2.0  HW4S           Right Panel  Panel      G
# M1       3.0  HW4S             Top Panel  Panel      G
# M1       5.0  HW4S       Left Back Panel  Panel    NaN
# M1       6.0  HW4S      Right Back Panel  Panel    NaN
# ...      ...   ...                   ...    ...    ...
# M1       3.0   WOU     Visible Top Panel  Panel    NaN
# M1       4.0   WOU  Visible Bottom Panel  Panel    NaN
# M1       5.0   WOU    Visible Back Panel  Panel    NaN
# M1       6.0   WOU         Bottom Ripper  Panel    NaN
# M1       7.0   WOU            Top Ripper  Panel    NaN
#
#                 EXTERNAL SHADE  \
# POSN
# M1      Frosty White 22291(SF)
# M1      Frosty White 22291(SF)
# M1      Frosty White 22291(SF)
# M1      Frosty White 22291(SF)
# M1      Frosty White 22291(SF)
# ...                        ...
# M1    Toned Blue 22212 MR PLUS
# ...

# %%
df.head()
# Out:
#       SL\nNO  CODE       DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# POSN
# M1       1.0  HW4S        Left Panel  Panel      G  Frosty White 22291(SF)
# M1       2.0  HW4S       Right Panel  Panel      G  Frosty White 22291(SF)
# M1       3.0  HW4S         Top Panel  Panel      G  Frosty White 22291(SF)
# M1       5.0  HW4S   Left Back Panel  Panel    NaN  Frosty White 22291(SF)
# M1       6.0  HW4S  Right Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                             PANEL CORE          INTERNAL SHADE  \
# POSN
# M1    MR - Green/Century or Equivalent  Frosty White 22291(SF)
# M1    MR - Green/Century or Equivalent  Frosty White 22291(SF)
# M1    MR - Green/Century or Equivalent  Frosty White 22291(SF)
# M1    MR - Green/Century or Equivalent  Frosty White 22291(SF)
# M1    MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                              BOARD NAME  GRAIN  ...  \
# ...

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#   POSN  SL\nNO  CODE       DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0   M1     1.0  HW4S        Left Panel  Panel      G  Frosty White 22291(SF)
# 1   M1     2.0  HW4S       Right Panel  Panel      G  Frosty White 22291(SF)
# 2   M1     3.0  HW4S         Top Panel  Panel      G  Frosty White 22291(SF)
# 3   M1     5.0  HW4S   Left Back Panel  Panel    NaN  Frosty White 22291(SF)
# 4   M1     6.0  HW4S  Right Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Base Price  \
# ...

# %%
d = {"key1" : [1,2,3,4],
     "key2" : [4,5,6,7],
     "key3" : [8,9,10,11]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     4     8
# 1     2     5     9
# 2     3     6    10
# 3     4     7    11

# %%
d1= {"key1" : (1,2,3,4),
     "key2" : (4,5,6,7),
     "key3" : (8,9,10,11)}

# %%
pd.DataFrame(d1)
# Out:
#    key1  key2  key3
# 0     1     4     8
# 1     2     5     9
# 2     3     6    10
# 3     4     7    11

# %%
import pandas as pd

# %%
df3 = pd.read_csv(r"C:\Users\SqyUser\Desktop\learning Classes\Python\vaibhav1.csv")

# %%
df3.head()
# Out:
#    SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0     1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1     2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2     3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3     4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4     5.0   M1  HW4S  Left Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Base Price  \
# ...

# %%
df3.columns
# Out:
# Index(['SL\nNO', 'POSN', 'CODE', 'DESCRIPTION', 'TYPE', 'GROOVE',
#        'EXTERNAL SHADE', 'PANEL CORE', 'INTERNAL SHADE', 'BOARD NAME', 'GRAIN',
#        'WIDTH', 'HEIGHT', 'THK', 'Sq Feet', 'Edge Bending Rate', 'Plywood',
#        'Internal laminate', 'External laminate', 'Processing Cost',
#        'Core Price', 'Plywood + Processing', 'Edge Banding Length & Price',
#        'Panel Price', 'Core \nBase Price', 'Core \nMarkup', 'Core \nWastage',
#        'Core Total Price', 'Top Lam Base Price', 'Top Lam Markup',
#        'Top Lam Wastge', 'Top Lam \nPrice', 'Bot Lam Base Price',
#        'Bot Lam Markup', 'Bot Lam Wastage', 'Bot Lam \nPrice',
#        'Edge Band \nBase Price', 'Edge Band\nLength', 'Edge Band\nPrice',
#        'Total Customer Price', 'Total Vendor Price',
#        'Percentage Vendor vs Customer'],
#       dtype='object')

# %%
df3['Sq Feet']
# Out:
# 0      13.11
# 1      13.11
# 2       9.76
# 3       9.76
# 4      16.74
#        ...
# 500      NaN
# 501      NaN
# 502     2.25
# 503     1.82
# 504      NaN
# Name: Sq Feet, Length: 505, dtype: float64

# %%
df3.dropna()### Dropped NaN(Null) Values
# Out:
#      SL\nNO POSN                     CODE          DESCRIPTION   TYPE GROOVE  \
# 0       1.0   M1                     HW4S           Left Panel  Panel      G
# 1       2.0   M1                     HW4S          Right Panel  Panel      G
# 2       3.0   M1                     HW4S            Top Panel  Panel      G
# 3       4.0   M1                     HW4S         Bottom Panel  Panel      G
# 47     48.0   M4                     HW1S  Visible Right Panel  Panel      G
# ..      ...  ...                      ...                  ...    ...    ...
# 482    86.0  M21  1D-BPO-BothSidePanel-CK          Right Panel  Panel      G
# 487    91.0  M23          2BS-BothSide-CK           Left Panel  Panel      G
# 488    92.0  M23          2BS-BothSide-CK          Right Panel  Panel      G
# 492    96.0  M24    3D Base BothPanels-CK           Left Panel  Panel      G
# 493    97.0  M24    3D Base BothPanels-CK          Right Panel  Panel      G
#
#              EXTERNAL SHADE  \
# ...

# %%
df3
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 3       4.0   M1                   HW4S                  Bottom Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df3.dropna(axis=1)
# Out:
#     Total Customer Price Total Vendor Price Percentage Vendor vs Customer
# 0               4,710.62            1948.78                        41.37%
# 1               4,710.62            1948.78                        41.37%
# 2               3,528.37            1456.19                        41.27%
# 3               3,528.37            1456.19                        41.27%
# 4               4,525.27            1883.61                        41.62%
# ..                   ...                ...                           ...
# 500             1,141.80             473.18                        41.44%
# 501               371.43             139.26                        37.49%
# 502                808.4             314.97                        38.96%
# 503               672.02             259.38                        38.60%
# 504           512,895.59         224,215.97                        43.72%
#
# [505 rows x 3 columns]

# %%
df3
# Out:
#      SL\nNO POSN                   CODE                   DESCRIPTION  \
# 0       1.0   M1                   HW4S                    Left Panel
# 1       2.0   M1                   HW4S                   Right Panel
# 2       3.0   M1                   HW4S                     Top Panel
# 3       4.0   M1                   HW4S                  Bottom Panel
# 4       5.0   M1                   HW4S               Left Back Panel
# ..      ...  ...                    ...                           ...
# 500   104.0  M24  3D Base BothPanels-CK                 Bottom Drawer
# 501   105.0  M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502   106.0  M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503   107.0  M25                 VGP-CF                Vertical Panel
# 504     NaN  NaN                    NaN                           NaN
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df3.fillna("amit", inplace = True)

# %%
df3
# Out:
#     SL\nNO  POSN                   CODE                   DESCRIPTION  \
# 0      1.0    M1                   HW4S                    Left Panel
# 1      2.0    M1                   HW4S                   Right Panel
# 2      3.0    M1                   HW4S                     Top Panel
# 3      4.0    M1                   HW4S                  Bottom Panel
# 4      5.0    M1                   HW4S               Left Back Panel
# ..     ...   ...                    ...                           ...
# 500  104.0   M24  3D Base BothPanels-CK                 Bottom Drawer
# 501  105.0   M24  3D Base BothPanels-CK     Innotech Back Panel (Big)
# 502  106.0   M24  3D Base BothPanels-CK  Innotech Bottom Panel (470D)
# 503  107.0   M25                 VGP-CF                Vertical Panel
# 504   amit  amit                   amit                          amit
#
#         TYPE GROOVE            EXTERNAL SHADE  \
# 0      Panel      G    Frosty White 22291(SF)
# ...

# %%
df3.head()
# Out:
#   SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0    1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1    2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2    3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3    4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4    5.0   M1  HW4S  Left Back Panel  Panel   amit  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ... Bot Lam Base Price  \
# ...

# %%
df3.groupby('Bot Lam Base Price')

# %%
df3.groupby('Bot Lam Base Price').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df3.groupby('Bot Lam Base Price').sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# ...

# %%
df3.head()
# Out:
#   SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0    1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1    2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2    3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3    4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4    5.0   M1  HW4S  Left Back Panel  Panel   amit  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ... Bot Lam Base Price  \
# ...

# %%
df3.groupby('Total Vendor Price').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df3.groupby('Total Vendor Price').sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# ...

# %%
df3.transpose()
# Out:
#                                                                              0    \
# SL\nNO                                                                       1.0
# POSN                                                                          M1
# CODE                                                                        HW4S
# DESCRIPTION                                                           Left Panel
# TYPE                                                                       Panel
# GROOVE                                                                         G
# EXTERNAL SHADE                                            Frosty White 22291(SF)
# PANEL CORE                                      MR - Green/Century or Equivalent
# INTERNAL SHADE                                            Frosty White 22291(SF)
# BOARD NAME                     Frosty White 22291(SF)_18MR_Frosty White 22291...
# GRAIN                                                                        0.0
# ...

# %%
df3.head()
# Out:
#   SL\nNO POSN  CODE      DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0    1.0   M1  HW4S       Left Panel  Panel      G  Frosty White 22291(SF)
# 1    2.0   M1  HW4S      Right Panel  Panel      G  Frosty White 22291(SF)
# 2    3.0   M1  HW4S        Top Panel  Panel      G  Frosty White 22291(SF)
# 3    4.0   M1  HW4S     Bottom Panel  Panel      G  Frosty White 22291(SF)
# 4    5.0   M1  HW4S  Left Back Panel  Panel   amit  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ... Bot Lam Base Price  \
# ...

# %%
df4 =  df[['SL\nNO', 	'POSN', 	'CODE', 'DESCRIPTION']]	[0:5]

# %%
df4
# Out:
#    SL\nNO POSN  CODE       DESCRIPTION
# 0     1.0   M1  HW4S        Left Panel
# 1     2.0   M1  HW4S       Right Panel
# 2     3.0   M1  HW4S         Top Panel
# 3     5.0   M1  HW4S   Left Back Panel
# 4     6.0   M1  HW4S  Right Back Panel

# %%
df5 =  df[['SL\nNO', 	'POSN', 	'CODE', 'DESCRIPTION']]	[5:10]

# %%
df5
# Out:
#    SL\nNO POSN  CODE       DESCRIPTION
# 5     7.0   M1  HW4S   Divider Panel 1
# 6     8.0   M1  HW4S        Back Patta
# 7     9.0   M1  HW4S      Middle Patta
# 8    10.0   M1  HW4S  Visible Skirting
# 9    11.0   M1  HW4S      Left Shutter

# %%
pd.concat([df4,df5])
# Out:
#    SL\nNO POSN  CODE       DESCRIPTION
# 0     1.0   M1  HW4S        Left Panel
# 1     2.0   M1  HW4S       Right Panel
# 2     3.0   M1  HW4S         Top Panel
# 3     5.0   M1  HW4S   Left Back Panel
# 4     6.0   M1  HW4S  Right Back Panel
# 5     7.0   M1  HW4S   Divider Panel 1
# 6     8.0   M1  HW4S        Back Patta
# 7     9.0   M1  HW4S      Middle Patta
# 8    10.0   M1  HW4S  Visible Skirting
# 9    11.0   M1  HW4S      Left Shutter

# %%
pd.concat([df4,df5],axis = 1)
# Out:
#    SL\nNO POSN  CODE       DESCRIPTION  SL\nNO POSN  CODE       DESCRIPTION
# 0     1.0   M1  HW4S        Left Panel     NaN  NaN   NaN               NaN
# 1     2.0   M1  HW4S       Right Panel     NaN  NaN   NaN               NaN
# 2     3.0   M1  HW4S         Top Panel     NaN  NaN   NaN               NaN
# 3     5.0   M1  HW4S   Left Back Panel     NaN  NaN   NaN               NaN
# 4     6.0   M1  HW4S  Right Back Panel     NaN  NaN   NaN               NaN
# 5     NaN  NaN   NaN               NaN     7.0   M1  HW4S   Divider Panel 1
# 6     NaN  NaN   NaN               NaN     8.0   M1  HW4S        Back Patta
# 7     NaN  NaN   NaN               NaN     9.0   M1  HW4S      Middle Patta
# 8     NaN  NaN   NaN               NaN    10.0   M1  HW4S  Visible Skirting
# 9     NaN  NaN   NaN               NaN    11.0   M1  HW4S      Left Shutter

# %%
df6 = pd.concat([df4,df5],axis = 1)

# %%
df6
# Out:
#    SL\nNO POSN  CODE       DESCRIPTION  SL\nNO POSN  CODE       DESCRIPTION
# 0     1.0   M1  HW4S        Left Panel     NaN  NaN   NaN               NaN
# 1     2.0   M1  HW4S       Right Panel     NaN  NaN   NaN               NaN
# 2     3.0   M1  HW4S         Top Panel     NaN  NaN   NaN               NaN
# 3     5.0   M1  HW4S   Left Back Panel     NaN  NaN   NaN               NaN
# 4     6.0   M1  HW4S  Right Back Panel     NaN  NaN   NaN               NaN
# 5     NaN  NaN   NaN               NaN     7.0   M1  HW4S   Divider Panel 1
# 6     NaN  NaN   NaN               NaN     8.0   M1  HW4S        Back Patta
# 7     NaN  NaN   NaN               NaN     9.0   M1  HW4S      Middle Patta
# 8     NaN  NaN   NaN               NaN    10.0   M1  HW4S  Visible Skirting
# 9     NaN  NaN   NaN               NaN    11.0   M1  HW4S      Left Shutter

# %%
df6.fillna("amit")
# Out:
#   SL\nNO  POSN  CODE       DESCRIPTION SL\nNO  POSN  CODE       DESCRIPTION
# 0    1.0    M1  HW4S        Left Panel   amit  amit  amit              amit
# 1    2.0    M1  HW4S       Right Panel   amit  amit  amit              amit
# 2    3.0    M1  HW4S         Top Panel   amit  amit  amit              amit
# 3    5.0    M1  HW4S   Left Back Panel   amit  amit  amit              amit
# 4    6.0    M1  HW4S  Right Back Panel   amit  amit  amit              amit
# 5   amit  amit  amit              amit    7.0    M1  HW4S   Divider Panel 1
# 6   amit  amit  amit              amit    8.0    M1  HW4S        Back Patta
# 7   amit  amit  amit              amit    9.0    M1  HW4S      Middle Patta
# 8   amit  amit  amit              amit   10.0    M1  HW4S  Visible Skirting
# 9   amit  amit  amit              amit   11.0    M1  HW4S      Left Shutter

# %%
data1 = pd.DataFrame({"key1" : [1,2,3,4],
                      "key2" : [4,5,6,7],
                      "key3" : [8,9,10,11]
})

# %%
data2 = pd.DataFrame({"key11" : [12,13,14,15],
     "key12" : [16,17,18,19],
     "key13" : [20,21,22,23]})

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     8
# b     2     5     9
# c     3     6    10
# d     4     7    11

# %%
data2
# Out:
#    key11  key12  key13
# 0     12     16     20
# 1     13     17     21
# 2     14     18     22
# 3     15     19     23

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     8
# b     2     5     9
# c     3     6    10
# d     4     7    11

# %%
data2
# Out:
#    key11  key12  key13
# 0     12     16     20
# 1     13     17     21
# 2     14     18     22
# 3     15     19     23

# %%
data1 = pd.DataFrame({"key1" : [1,2,3,4],
                      "key2" : [4,5,6,7],
                      "key3" : [8,9,10,11]
},
                     index = ['a','b','c','d'])

# %%
data2 = pd.DataFrame({"key11" : [12,13,14,15],
                      "key12" : [16,17,18,19],
                      "key13" : [20,21,22,23]
},index = ['a','b','h','i'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     8
# b     2     5     9
# c     3     6    10
# d     4     7    11

# %%
data2
# Out:
#    key1  key2  key3
# a    12    16    20
# b    13    17    21
# h    14    18    22
# i    15    19    23

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key12  key13
# a     1     4     8   12.0   16.0   20.0
# b     2     5     9   13.0   17.0   21.0
# c     3     6    10    NaN    NaN    NaN
# d     4     7    11    NaN    NaN    NaN

# %%
data1.join(data2, how = 'inner')
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3, key11, key12, key13]
# Index: []

# %%
data1.join(data2, how = 'right')
# Out:
#    key1  key2  key3  key11  key12  key13
# 0   NaN   NaN   NaN     12     16     20
# 1   NaN   NaN   NaN     13     17     21
# 2   NaN   NaN   NaN     14     18     22
# 3   NaN   NaN   NaN     15     19     23

# %%
data1.join(data2, how = 'outer')
# Out:
#    key1  key2  key3  key11  key12  key13
# a   1.0   4.0   8.0    NaN    NaN    NaN
# b   2.0   5.0   9.0    NaN    NaN    NaN
# c   3.0   6.0  10.0    NaN    NaN    NaN
# d   4.0   7.0  11.0    NaN    NaN    NaN
# 0   NaN   NaN   NaN   12.0   16.0   20.0
# 1   NaN   NaN   NaN   13.0   17.0   21.0
# 2   NaN   NaN   NaN   14.0   18.0   22.0
# 3   NaN   NaN   NaN   15.0   19.0   23.0

# %%
data1.join(data2, how = 'cross')
# Out:
#     key1  key2  key3  key11  key12  key13
# 0      1     4     8     12     16     20
# 1      1     4     8     13     17     21
# 2      1     4     8     14     18     22
# 3      1     4     8     15     19     23
# 4      2     5     9     12     16     20
# 5      2     5     9     13     17     21
# 6      2     5     9     14     18     22
# 7      2     5     9     15     19     23
# 8      3     6    10     12     16     20
# 9      3     6    10     13     17     21
# 10     3     6    10     14     18     22
# 11     3     6    10     15     19     23
# 12     4     7    11     12     16     20
# 13     4     7    11     13     17     21
# 14     4     7    11     14     18     22
# 15     4     7    11     15     19     23

# %%
df.head()
# Out:
#   POSN  SL\nNO  CODE       DESCRIPTION   TYPE GROOVE          EXTERNAL SHADE  \
# 0   M1     1.0  HW4S        Left Panel  Panel      G  Frosty White 22291(SF)
# 1   M1     2.0  HW4S       Right Panel  Panel      G  Frosty White 22291(SF)
# 2   M1     3.0  HW4S         Top Panel  Panel      G  Frosty White 22291(SF)
# 3   M1     5.0  HW4S   Left Back Panel  Panel    NaN  Frosty White 22291(SF)
# 4   M1     6.0  HW4S  Right Back Panel  Panel    NaN  Frosty White 22291(SF)
#
#                          PANEL CORE          INTERNAL SHADE  \
# 0  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 1  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 2  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 3  MR - Green/Century or Equivalent  Frosty White 22291(SF)
# 4  MR - Green/Century or Equivalent  Frosty White 22291(SF)
#
#                                           BOARD NAME  ...  Bot Lam Base Price  \
# ...
